# %%
import pandas as pd
import numpy as np
import os

print(os.path.exists("analysis_covid-19/result_entities_covid-19.tsv"))

new_file = pd.read_csv('analysis_covid-19/result_entities_covid-19.tsv',delimiter='\t',on_bad_lines='warn')
print(np.sum(new_file['total_count']))
new_file
# Out:
# True
# 1610695
#                                              Unnamed: 0  total_count  \
# 0                                              COVID 19      1168839
# 1                                   coronavirus disease        74663
# 2                              coronavirus disease 2019        58002
# 3                                              Covid 19        57151
# 4                                       CoV 2 infection        44265
# ...                                                 ...          ...
# 1504                           Covid 19 Virus infection            1
# 1505                           infection caused by nCoV            1
# 1506  Coronavirus disease (COVID 19) caused by SARS ...            1
# 1507                 COVID 19 novel coronavirus disease            1
# 1508            Coronavirus Severe Respiratory Syndrome            1
#
#       articles_spanned  batches_spanned  freq_per_article  freq_per_batch  \
# ...

# %%
import pandas as pd
import numpy as np

new_file = pd.read_csv('analysis_Sars_cov2/result_entities_Sars_cov2.tsv',delimiter='\t',on_bad_lines='warn')
print(np.sum(new_file['total_count']))
new_file
# Out:
# 848179
#                                           Unnamed: 0  total_count  \
# 0                                         SARS CoV 2       350581
# 1                                        coronavirus       204183
# 2                                        Coronavirus        42346
# 3           acute respiratory syndrome coronavirus 2        37771
# 4    severe acute respiratory syndrome coronavirus 2        32566
# ..                                               ...          ...
# 611                                       SARs cov 2            1
# 612                                  new COronaVIrus            1
# 613                                        Novel COV            1
# 614                                 Sars Cov 2 Virus            1
# 615                                 SARs Cov 2 virus            1
#
#      articles_spanned  batches_spanned  freq_per_article  freq_per_batch  \
# 0              130133              748          2.694021      468.691176
# ...

# %%
import pandas as pd
import numpy as np

new_file = pd.read_csv('analysis_SarsCov2_variant/result_entities_SarsCov2_variant.tsv',delimiter='\t',on_bad_lines='warn')
print(np.sum(new_file['total_count']))
new_file
# Out:
# 80825
#           Unnamed: 0  total_count  articles_spanned  batches_spanned  \
# 0            Omicron         8764              2555              649
# 1              Delta         8484              3662              700
# 2              alpha         7343              5061              762
# 3               beta         6832              4650              762
# 4              gamma         3856              2703              729
# ..               ...          ...               ...              ...
# 991          B.1.139            1                 1                1
# 992       variant Hb            1                 1                1
# 993          B.1.218            1                 1                1
# 994          B.1.260            1                 1                1
# 995  B.1.1.7 Lineage            1                 1                1
#
#      freq_per_article  freq_per_batch  \
# 0            3.430137       13.503852
# 1            2.316767       12.120000
# ...

# %%
new_file = pd.read_csv('analysis_SarsCov2_mutation/result_entities_SarsCov2_mutation.tsv',delimiter='\t',on_bad_lines='warn')
print(np.sum(new_file['total_count']))
new_file
# Out:
# 5786
#      Unnamed: 0  total_count  articles_spanned  batches_spanned  \
# 0         D614G         2092              1319              554
# 1         N501Y         1280               744              413
# 2         L452R          492               281              209
# 3         K417N          361               260              204
# 4         E484Q          170               105               95
# 5         P681H          140               101               90
# 6         P681R          133                90               85
# 7         S477N          127                94               82
# 8         Y453F           77                56               50
# 9         E484K           61                54               52
# 10        K417T           50                45               39
# 11      K417N/T           47                42               41
# 12        S494P           47                34               32
# 13        Q493R           44                38               38
# ...
